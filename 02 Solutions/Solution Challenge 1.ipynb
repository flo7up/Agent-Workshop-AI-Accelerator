# %%
import logging
import os
import requests
import json
from typing import Any, Callable, Set
import datetime

# Azure AI Projects and authentication
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import FunctionTool, ToolSet
from azure.identity import AzureCliCredential

# Azure Blob Storage client
from azure.storage.blob import BlobServiceClient

# Load environment variables from the .env file
from dotenv import load_dotenv
from pathlib import Path

# Construct the path to the .env file in the parent directory
env_path = Path().resolve().parent.parent / ".env"

# Load environment variables from the specified .env file
load_dotenv(dotenv_path=env_path)


# Retrieve keys from environment variables
BING_API_KEY = os.getenv("BING_API_KEY")
PROJECT_CONNECTION_STRING = os.getenv("PROJECT_CONNECTION_STRING")
AZURE_STORAGE_CONNECTION_STRING = os.getenv("AZURE_STORAGE_CONNECTION_STRING")

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

if not BING_API_KEY:
    raise ValueError("BING_API_KEY is not set in the .env file.")
if not PROJECT_CONNECTION_STRING:
    raise ValueError("PROJECT_CONNECTION_STRING is not set in the .env file.")
if not AZURE_STORAGE_CONNECTION_STRING:
    raise ValueError("AZURE_STORAGE_CONNECTION_STRING is not set in the .env file.")




def search_for_relevant_news(query: str = "Artificial Intelligence", news_count: int = 10) -> str:
    """
    Uses the Bing Search API to fetch news articles related to the query.
    
    Args:
        query (str): The search term. Defaults to "Artificial Intelligence".
        news_count (int): Number of articles to return. Defaults to 10.
    
    Returns:
        A JSON-formatted string containing a list of news articles (title and URL).
    """
    logging.info(f"Searching for news articles related to: {query}")
    endpoint = "https://api.bing.microsoft.com/v7.0/news/search"
    params = {"q": query, "mkt": "en-US", "count": news_count}
    headers = {"Ocp-Apim-Subscription-Key": BING_API_KEY}

    try:
        response = requests.get(endpoint, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        news_list = []
        for item in data.get("value", []):
            news_entry = {
                "title": item.get("name", "No Title"),
                "url": item.get("url", "No URL"),
            }
            news_list.append(news_entry)
        return json.dumps(news_list, indent=4)
    except Exception as e:
        logging.error(f"Error calling Bing Search API: {e}")
        return json.dumps({"error": str(e)})


def store_thought_process_in_blob(thought_summary: str) -> str:
    """
    Uploads the agent's thought process summary to an Azure Blob Storage container.

    Args:
        thought_summary (str): A text summary of the agent's thought process.
        container_name (str): Name of the container in Blob Storage.

    Returns:
        str: A message indicating success or failure.
    """
    container_name = "thoughts"
    try:
        # Create a BlobServiceClient using the storage connection string.
        blob_service_client = BlobServiceClient.from_connection_string(AZURE_STORAGE_CONNECTION_STRING)
        # Get the container client.
        container_client = blob_service_client.get_container_client(container_name)

        # Create the container if it does not exist.
        try:
            container_client.create_container()
            logging.info(f"Container '{container_name}' created.")
        except Exception as e:
            logging.info(f"Container '{container_name}' may already exist: {e}")

        # Create a timestamp for a unique file name.
        timestamp = datetime.datetime.utcnow().strftime("%Y%m%d%H%M%S")
        blob_name = f"thoughts{timestamp}.txt"

        # Get a blob client and upload the text data.
        blob_client = container_client.get_blob_client(blob_name)
        blob_client.upload_blob(thought_summary, overwrite=True)
        success_message = f"Thought process successfully stored in blob storage: {container_name}/{blob_name}"
        logging.info(success_message)
        return success_message
    except Exception as e:
        error_message = f"Error uploading thought process to blob storage: {e}"
        logging.error(error_message)
        return error_message
    

def store_news_in_blob(news_json: str) -> str:
    """
    Uploads the provided news JSON data to an Azure Blob Storage container and returns a success or error message.

    Args:
        news_json (str): JSON formatted string containing news data.
        container_name (str): Name of the container in Blob Storage.

    Returns:
        str: A message indicating success or failure.
    """
    container_name = "news"
    try:
        # Create a BlobServiceClient using the storage connection string.
        blob_service_client = BlobServiceClient.from_connection_string(AZURE_STORAGE_CONNECTION_STRING)
        # Get the container client.
        container_client = blob_service_client.get_container_client(container_name)

        # Create the container if it does not exist.
        try:
            container_client.create_container()
            logging.info(f"Container '{container_name}' created.")
        except Exception as e:
            logging.info(f"Container '{container_name}' may already exist: {e}")

        # Create a timestamp for a unique file name.
        timestamp = datetime.datetime.utcnow().strftime("%Y%m%d%H%M%S")
        blob_name = f"news{timestamp}.json"

        # Get a blob client and upload the JSON data.
        blob_client = container_client.get_blob_client(blob_name)
        blob_client.upload_blob(news_json, overwrite=True)
        success_message = f"News data successfully stored in blob storage: {container_name}/{blob_name}"
        logging.info(success_message)
        return success_message
    except Exception as e:
        error_message = f"Error uploading news data to blob storage: {e}"
        logging.error(error_message)
        return error_message

# ---------------------------------------------------------------------------
# Prepare the tool for the Azure AI Agent service.
# We wrap our search function in a FunctionTool and add it to a ToolSet.
# ---------------------------------------------------------------------------

user_functions: Set[Callable[..., Any]] = {
    search_for_relevant_news,
    store_news_in_blob, #<-- Uncomment to add this function
    store_thought_process_in_blob #<-- Uncomment to add this function
}
functions = FunctionTool(user_functions)
toolset = ToolSet()
toolset.add(functions)

def run_agent():
    """
    Runs the Azure AI Agent pipeline.
    
    The agent uses the Bing Search API tool to fetch the latest AI news.
    It creates a simple conversation thread where the user message triggers the tool.
    """
    logging.info("Starting the Azure AI Agent pipeline...")
    # Create the Azure AI Projects client with a connection string and default credential.
    client = AIProjectClient.from_connection_string(
        credential=AzureCliCredential(),
        conn_str=PROJECT_CONNECTION_STRING,
        
    )
    
    #<-- This is a simple agent that fetches the latest AI news. -->
    #<-- It uses the Bing Search API tool to get the news. -->
    #<-- Uncomment the rows to allow the agent store the news in Azure Blob Storage. -->

    # Instructions for the agent
    instructions = """ 
    You are a helpful agent that provides the latest news articles about AI.
    Always se the 'search_for_relevant_news' function to fetch and return current AI news.
    Then store the news data in Azure Blob Storage using the 'store_news_in_blob' function.
    At the end, summarize your thought process and store it in Azure Blob Storage using the 'store_thought_process_in_blob' function.
    """
    
    with client:
        # Create the agent using a chosen model (e.g., gpt-4o-mini)
        agent = client.agents.create_agent(
            model="gpt-4o-mini",
            name="simple-news-agent",
            instructions=instructions,
            toolset=toolset
        )
        logging.info(f"Created agent with ID: {agent.id}")

        # Start a new conversation thread
        thread = client.agents.create_thread()
        logging.info(f"Created thread with ID: {thread.id}")

        # Create an initial user message
        message = client.agents.create_message(
            thread_id=thread.id,
            role="user",
            content="Show me the latest AI news."
        )
        logging.info(f"User message created with ID: {message.id}")

        # Process the conversation
        run = client.agents.create_and_process_run(
            thread_id=thread.id,
            assistant_id=agent.id
        )
        logging.info(f"Run finished with status: {run.status}")

        if run.status == "failed":
            logging.error(f"Run failed: {run.last_error}")
        else:
            # Retrieve and log all messages from the conversation
            messages = client.agents.list_messages(thread_id=thread.id)
            for msg in messages["data"]:
                if msg["role"] == "assistant":
                    logging.info("Assistant response:")
                    for part in msg["content"]:
                        if part["type"] == "text":
                            logging.info(part["text"]["value"])

        # Cleanup the agent after the run
        client.agents.delete_agent(agent.id)
        logging.info("Agent deleted successfully.")


run_agent()
# Out:
# 2025-03-01 17:31:50,040 - INFO - Starting the Azure AI Agent pipeline...
# 2025-03-01 17:31:53,356 - INFO - AzureCliCredential.get_token succeeded
# 2025-03-01 17:31:53,358 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/assistants?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '1535'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'ad1c1110-f6ba-11ef-b045-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-03-01 17:31:56,344 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:31:56 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:31:56,348 - INFO - Created agent with ID: asst_ZAlCg6ucjKqZ50HBOJaK6qEK
# 2025-03-01 17:31:56,350 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '2'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b0dea0b0-f6ba-11ef-9bef-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-03-01 17:31:56,816 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:31:57 GMT'
#     'Content-Type': 'application/json'
#     'Content-Length': '137'
#     'Connection': 'keep-alive'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
# 2025-03-01 17:31:56,816 - INFO - Created thread with ID: thread_yB7wJnIuqJaneXJ7fs2As9r6
# 2025-03-01 17:31:56,818 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/messages?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '58'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b1260bf6-f6ba-11ef-b288-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-03-01 17:31:57,245 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:31:57 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:31:57,247 - INFO - User message created with ID: msg_Y6GAKqDCOmHadZJI6UshnpbX
# 2025-03-01 17:31:57,249 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '66'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b1679e3d-f6ba-11ef-80e5-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-03-01 17:31:59,096 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:31:59 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:00,101 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b31b03ac-f6ba-11ef-a05f-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:00,720 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:01 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:00,723 - INFO - Searching for news articles related to: AI
# 2025-03-01 17:32:01,849 - INFO - Tool outputs: [{'tool_call_id': 'call_GbRvvTCDBFk4G5DcMn3oT0rW', 'output': '[\n    {\n        "title": "Analysts rethink stock price target for Nvidia\\u2019s key AI partner",\n        "url": "https://www.msn.com/en-us/technology/tech-companies/analysts-rethink-stock-price-target-for-nvidia-s-key-ai-partner/ar-AA1A32CN"\n    },\n    {\n        "title": "Tinkerers got the Humane AI Pin working again.",\n        "url": "https://www.theverge.com/news/622252/tinkerers-got-the-humane-ai-pin-working-again"\n    },\n    {\n        "title": "AI Is Changing How We Learn: The New Role Of Human Teachers",\n        "url": "https://www.forbes.com/sites/corneliawalther/2025/03/01/ai-is-changing-how-we-learn-the-new-role-of-human-teachers/"\n    },\n    {\n        "title": "5 AI Stocks To Buy Ahead Of The Stargate AI Project",\n        "url": "https://www.forbes.com/sites/investor-hub/article/top-ai-stocks-buy-ahead-of-stargate-ai-project/"\n    },\n    {\n        "title": "This education startup is using AI to help students learn. It says tech should never replace human teachers",\n        "url": "https://www.msn.com/en-us/technology/artificial-intelligence/this-education-startup-is-using-ai-to-help-students-learn-it-says-tech-should-never-replace-human-teachers/ar-AA1A2Lqn"\n    }\n]'}]
# 2025-03-01 17:32:01,851 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F/submit_tool_outputs?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '1355'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b425e80e-f6ba-11ef-a591-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-03-01 17:32:02,312 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:02 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:02,312 - INFO - Current run status: RunStatus.REQUIRES_ACTION
# 2025-03-01 17:32:03,315 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b5056f02-f6ba-11ef-b7b8-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:03,627 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:04 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:03,630 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-03-01 17:32:04,631 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b5ce2e85-f6ba-11ef-ae14-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:05,243 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:05 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:05,245 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-03-01 17:32:06,247 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b6c4cbbd-f6ba-11ef-9c93-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:06,524 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:07 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:06,528 - INFO - Request URL: 'https://storageaccountnewstest.blob.core.windows.net/news?restype=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b6efacae-f6ba-11ef-a1fb-8cc681cfef94'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:07,270 - INFO - Response status: 403
# Response headers:
#     'Content-Length': '269'
#     'Content-Type': 'application/xml'
#     'Server': 'Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4b9e9776-101e-0043-6cc7-8a9da5000000'
#     'x-ms-error-code': 'KeyBasedAuthenticationNotPermitted'
#     'Date': 'Sat, 01 Mar 2025 16:32:06 GMT'
# 2025-03-01 17:32:07,274 - INFO - Container 'news' may already exist: Key based authentication is not permitted on this storage account.
# RequestId:4b9e9776-101e-0043-6cc7-8a9da5000000
# Time:2025-03-01T16:32:07.7688289Z
# ErrorCode:KeyBasedAuthenticationNotPermitted
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>KeyBasedAuthenticationNotPermitted</Code><Message>Key based authentication is not permitted on this storage account.
# RequestId:4b9e9776-101e-0043-6cc7-8a9da5000000
# Time:2025-03-01T16:32:07.7688289Z</Message></Error>
# 2025-03-01 17:32:07,276 - INFO - Request URL: 'https://storageaccountnewstest.blob.core.windows.net/news/news20250301163207.json'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '1058'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'b761c9bb-f6ba-11ef-9f05-8cc681cfef94'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-03-01 17:32:07,317 - INFO - Response status: 403
# Response headers:
#     'Content-Length': '269'
#     'Content-Type': 'application/xml'
#     'Server': 'Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '4b9e9789-101e-0043-7ec7-8a9da5000000'
#     'x-ms-error-code': 'KeyBasedAuthenticationNotPermitted'
#     'Date': 'Sat, 01 Mar 2025 16:32:06 GMT'
# 2025-03-01 17:32:07,318 - ERROR - Error uploading news data to blob storage: Key based authentication is not permitted on this storage account.
# RequestId:4b9e9789-101e-0043-7ec7-8a9da5000000
# Time:2025-03-01T16:32:07.8156410Z
# ErrorCode:KeyBasedAuthenticationNotPermitted
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>KeyBasedAuthenticationNotPermitted</Code><Message>Key based authentication is not permitted on this storage account.
# RequestId:4b9e9789-101e-0043-7ec7-8a9da5000000
# Time:2025-03-01T16:32:07.8156410Z</Message></Error>
# 2025-03-01 17:32:07,319 - INFO - Tool outputs: [{'tool_call_id': 'call_WZ0jmfvgZOtlYFtWRCNxepsU', 'output': 'Error uploading news data to blob storage: Key based authentication is not permitted on this storage account.\nRequestId:4b9e9789-101e-0043-7ec7-8a9da5000000\nTime:2025-03-01T16:32:07.8156410Z\nErrorCode:KeyBasedAuthenticationNotPermitted\nContent: <?xml version="1.0" encoding="utf-8"?><Error><Code>KeyBasedAuthenticationNotPermitted</Code><Message>Key based authentication is not permitted on this storage account.\nRequestId:4b9e9789-101e-0043-7ec7-8a9da5000000\nTime:2025-03-01T16:32:07.8156410Z</Message></Error>'}]
# 2025-03-01 17:32:07,320 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F/submit_tool_outputs?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '621'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b7688ef2-f6ba-11ef-a0fa-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-03-01 17:32:07,923 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:08 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:07,925 - INFO - Current run status: RunStatus.REQUIRES_ACTION
# 2025-03-01 17:32:08,927 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b85db1e5-f6ba-11ef-b6f0-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:09,204 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:09 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:09,206 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-03-01 17:32:10,208 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b9212e2c-f6ba-11ef-8a7c-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:10,492 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:10 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:10,494 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-03-01 17:32:11,496 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'b9e5b413-f6ba-11ef-a029-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:11,765 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:12 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:11,767 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-03-01 17:32:12,769 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_yB7wJnIuqJaneXJ7fs2As9r6/runs/run_durftpfcXHZ2cYvJfqq7Bh8F?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'baa7fffc-f6ba-11ef-98fb-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:13,063 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:13 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-03-01 17:32:13,065 - INFO - Current run status: RunStatus.FAILED
# 2025-03-01 17:32:13,065 - INFO - Run finished with status: RunStatus.FAILED
# 2025-03-01 17:32:13,067 - ERROR - Run failed: {'code': 'rate_limit_exceeded', 'message': 'Rate limit is exceeded. Try again in 48 seconds.'}
# 2025-03-01 17:32:13,067 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/assistants/asst_ZAlCg6ucjKqZ50HBOJaK6qEK?api-version=REDACTED'
# Request method: 'DELETE'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'bad58015-f6ba-11ef-a21f-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-03-01 17:32:13,712 - INFO - Response status: 200
# Response headers:
#     'Date': 'Sat, 01 Mar 2025 16:32:14 GMT'
#     'Content-Type': 'application/json'
#     'Content-Length': '95'
#     'Connection': 'keep-alive'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
# 2025-03-01 17:32:13,712 - INFO - Agent deleted successfully.
