# %%
import logging
import os
import requests
import json
from typing import Any, Callable, Set
import datetime

# Azure AI Projects and authentication
from azure.ai.projects import AIProjectClient
from azure.ai.projects.models import FunctionTool, ToolSet
from azure.identity import AzureCliCredential

# Azure Blob Storage client
from azure.storage.blob import BlobServiceClient

# Load environment variables from the .env file
from dotenv import load_dotenv
from pathlib import Path

# Construct the path to the .env file in the parent directory
env_path = Path().resolve().parent.parent / ".env"

# Load environment variables from the specified .env file
load_dotenv(dotenv_path=env_path)


# Retrieve keys from environment variables
BING_API_KEY = os.getenv("BING_API_KEY")
PROJECT_CONNECTION_STRING = os.getenv("PROJECT_CONNECTION_STRING")
AZURE_STORAGE_CONNECTION_STRING = os.getenv("AZURE_STORAGE_CONNECTION_STRING")

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

if not BING_API_KEY:
    raise ValueError("BING_API_KEY is not set in the .env file.")
if not PROJECT_CONNECTION_STRING:
    raise ValueError("PROJECT_CONNECTION_STRING is not set in the .env file.")
if not AZURE_STORAGE_CONNECTION_STRING:
    raise ValueError("AZURE_STORAGE_CONNECTION_STRING is not set in the .env file.")




def search_for_relevant_news(query: str = "Artificial Intelligence", news_count: int = 10) -> str:
    """
    Uses the Bing Search API to fetch news articles related to the query.
    
    Args:
        query (str): The search term. Defaults to "Artificial Intelligence".
        news_count (int): Number of articles to return. Defaults to 10.
    
    Returns:
        A JSON-formatted string containing a list of news articles (title and URL).
    """
    logging.info(f"Searching for news articles related to: {query}")
    endpoint = "https://api.bing.microsoft.com/v7.0/news/search"
    params = {"q": query, "mkt": "en-US", "count": news_count}
    headers = {"Ocp-Apim-Subscription-Key": BING_API_KEY}

    try:
        response = requests.get(endpoint, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        news_list = []
        for item in data.get("value", []):
            news_entry = {
                "title": item.get("name", "No Title"),
                "url": item.get("url", "No URL"),
            }
            news_list.append(news_entry)
        return json.dumps(news_list, indent=4)
    except Exception as e:
        logging.error(f"Error calling Bing Search API: {e}")
        return json.dumps({"error": str(e)})


def store_thought_process_in_blob(thought_summary: str, container_name: str = "thoughts") -> str:
    """
    Uploads the agent's thought process summary to an Azure Blob Storage container.

    Args:
        thought_summary (str): A text summary of the agent's thought process.
        container_name (str): Name of the container in Blob Storage.

    Returns:
        str: A message indicating success or failure.
    """
    try:
        # Create a BlobServiceClient using the storage connection string.
        blob_service_client = BlobServiceClient.from_connection_string(AZURE_STORAGE_CONNECTION_STRING)
        # Get the container client.
        container_client = blob_service_client.get_container_client(container_name)

        # Create the container if it does not exist.
        try:
            container_client.create_container()
            logging.info(f"Container '{container_name}' created.")
        except Exception as e:
            logging.info(f"Container '{container_name}' may already exist: {e}")

        # Create a timestamp for a unique file name.
        timestamp = datetime.datetime.utcnow().strftime("%Y%m%d_%H%M%S")
        blob_name = f"thoughts_{timestamp}.txt"

        # Get a blob client and upload the text data.
        blob_client = container_client.get_blob_client(blob_name)
        blob_client.upload_blob(thought_summary, overwrite=True)
        success_message = f"Thought process successfully stored in blob storage: {container_name}/{blob_name}"
        logging.info(success_message)
        return success_message
    except Exception as e:
        error_message = f"Error uploading thought process to blob storage: {e}"
        logging.error(error_message)
        return error_message
    

def store_news_in_blob(news_json: str, container_name: str = "news") -> str:
    """
    Uploads the provided news JSON data to an Azure Blob Storage container and returns a success or error message.

    Args:
        news_json (str): JSON formatted string containing news data.
        container_name (str): Name of the container in Blob Storage.

    Returns:
        str: A message indicating success or failure.
    """
    try:
        # Create a BlobServiceClient using the storage connection string.
        blob_service_client = BlobServiceClient.from_connection_string(AZURE_STORAGE_CONNECTION_STRING)
        # Get the container client.
        container_client = blob_service_client.get_container_client(container_name)

        # Create the container if it does not exist.
        try:
            container_client.create_container()
            logging.info(f"Container '{container_name}' created.")
        except Exception as e:
            logging.info(f"Container '{container_name}' may already exist: {e}")

        # Create a timestamp for a unique file name.
        timestamp = datetime.datetime.utcnow().strftime("%Y%m%d_%H%M%S")
        blob_name = f"news_{timestamp}.json"

        # Get a blob client and upload the JSON data.
        blob_client = container_client.get_blob_client(blob_name)
        blob_client.upload_blob(news_json, overwrite=True)
        success_message = f"News data successfully stored in blob storage: {container_name}/{blob_name}"
        logging.info(success_message)
        return success_message
    except Exception as e:
        error_message = f"Error uploading news data to blob storage: {e}"
        logging.error(error_message)
        return error_message

# ---------------------------------------------------------------------------
# Prepare the tool for the Azure AI Agent service.
# We wrap our search function in a FunctionTool and add it to a ToolSet.
# ---------------------------------------------------------------------------

user_functions: Set[Callable[..., Any]] = {
    search_for_relevant_news,
    store_news_in_blob,
    store_thought_process_in_blob
}
functions = FunctionTool(user_functions)
toolset = ToolSet()
toolset.add(functions)

def run_agent():
    """
    Runs the Azure AI Agent pipeline.
    
    The agent uses the Bing Search API tool to fetch the latest AI news.
    It creates a simple conversation thread where the user message triggers the tool.
    """
    logging.info("Starting the Azure AI Agent pipeline...")
    # Create the Azure AI Projects client with a connection string and default credential.
    client = AIProjectClient.from_connection_string(
        credential=AzureCliCredential(),
        conn_str=PROJECT_CONNECTION_STRING,
        
    )
    
    # Instructions for the agent
    instructions = """
    You are a helpful assistant that provides the latest news articles about AI.
    Always se the 'search_for_relevant_news' function to fetch and return current AI news.
    Then store the news data in Azure Blob Storage using the 'store_news_in_blob' function.
    At the end, summarize your thought process and store it in Azure Blob Storage using the 'store_thought_process_in_blob' function.
    """
    
    with client:
        # Create the agent using a chosen model (e.g., gpt-4o-mini)
        agent = client.agents.create_agent(
            model="gpt-4o-mini",
            name="simple-news-agent",
            instructions=instructions,
            toolset=toolset
        )
        logging.info(f"Created agent with ID: {agent.id}")

        # Start a new conversation thread
        thread = client.agents.create_thread()
        logging.info(f"Created thread with ID: {thread.id}")

        # Create an initial user message
        message = client.agents.create_message(
            thread_id=thread.id,
            role="user",
            content="Show me the latest AI news."
        )
        logging.info(f"User message created with ID: {message.id}")

        # Process the conversation
        run = client.agents.create_and_process_run(
            thread_id=thread.id,
            assistant_id=agent.id
        )
        logging.info(f"Run finished with status: {run.status}")

        if run.status == "failed":
            logging.error(f"Run failed: {run.last_error}")
        else:
            # Retrieve and log all messages from the conversation
            messages = client.agents.list_messages(thread_id=thread.id)
            for msg in messages["data"]:
                if msg["role"] == "assistant":
                    logging.info("Assistant response:")
                    for part in msg["content"]:
                        if part["type"] == "text":
                            logging.info(part["text"]["value"])

        # Cleanup the agent after the run
        client.agents.delete_agent(agent.id)
        logging.info("Agent deleted successfully.")


run_agent()
# Out:
# 2025-02-25 14:25:21,431 - INFO - Starting the Azure AI Agent pipeline...
# 2025-02-25 14:25:22,685 - INFO - AzureCliCredential.get_token succeeded
# 2025-02-25 14:25:22,685 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/assistants?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '1680'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'f686b6f2-f37b-11ef-8bc6-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-02-25 14:25:23,634 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:24 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:23,636 - INFO - Created agent with ID: asst_OvZdVzilOpUumk54d2YVzX91
# 2025-02-25 14:25:23,636 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '2'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'f7d70212-f37b-11ef-be38-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-02-25 14:25:24,111 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:24 GMT'
#     'Content-Type': 'application/json'
#     'Content-Length': '137'
#     'Connection': 'keep-alive'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
# 2025-02-25 14:25:24,111 - INFO - Created thread with ID: thread_nVDfXSSu3gI9VipDlqITA4K6
# 2025-02-25 14:25:24,113 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/messages?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '58'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'f81fcb25-f37b-11ef-a649-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-02-25 14:25:24,567 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:25 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:24,568 - INFO - User message created with ID: msg_Pgc1Mf92oHdjt2VCCamZVjLH
# 2025-02-25 14:25:24,569 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '66'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'f865409d-f37b-11ef-8107-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-02-25 14:25:24,945 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:25 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:25,954 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'f938901a-f37b-11ef-803d-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:26,230 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:26 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:26,232 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-02-25 14:25:27,233 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'f9fbcad6-f37b-11ef-acfb-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:27,464 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:27 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:27,464 - INFO - Searching for news articles related to: artificial intelligence
# 2025-02-25 14:25:28,233 - INFO - Tool outputs: [{'tool_call_id': 'call_mbJHpomfmmcJmRFmy5rHhtmw', 'output': '[\n    {\n        "title": "How College Football Playoff and artificial intelligence outwit SEC, Big Ten",\n        "url": "https://www.msn.com/en-us/sports/other/how-college-football-playoff-and-artificial-intelligence-outwit-sec-big-ten/ar-AA1zKi5D"\n    },\n    {\n        "title": "The Rise of Artificial Intelligence at JPMorgan",\n        "url": "https://www.msn.com/en-us/technology/artificial-intelligence/the-rise-of-artificial-intelligence-at-jpmorgan/ar-AA1zGID8"\n    },\n    {\n        "title": "Got $1,000 and 10 years? Check out these 3 artificial intelligence stocks set to soar.",\n        "url": "https://www.usatoday.com/story/money/investing/2025/02/23/three-ai-stocks-set-to-soar/78281118007/"\n    },\n    {\n        "title": "10 takeaways for addressing artificial intelligence in 10-Ks",\n        "url": "https://www.reuters.com/legal/legalindustry/10-takeaways-addressing-artificial-intelligence-10-ks-2025-02-21/"\n    },\n    {\n        "title": "Leveraging Artificial Intelligence For Advancing Sustainability: Opportunities And Challenges",\n        "url": "https://www.forbes.com/councils/forbestechcouncil/2025/02/21/leveraging-artificial-intelligence-for-advancing-sustainability-opportunities-and-challenges/"\n    }\n]'}]
# 2025-02-25 14:25:28,234 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4/submit_tool_outputs?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '1392'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'fa948f37-f37b-11ef-8009-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-02-25 14:25:28,607 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:29 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:28,607 - INFO - Current run status: RunStatus.REQUIRES_ACTION
# 2025-02-25 14:25:29,612 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'fb66d02f-f37b-11ef-a468-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:29,955 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:30 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:29,955 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-02-25 14:25:30,957 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'fc3423f1-f37b-11ef-96c2-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:31,199 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:31 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:31,200 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-02-25 14:25:32,201 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'fcf1e5e1-f37b-11ef-a7c8-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:32,448 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:32 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:32,448 - INFO - Request URL: 'https://newaifoundry711371036146.blob.core.windows.net/ai-news?restype=REDACTED'
# Request method: 'PUT'
# Request headers:
#     'x-ms-version': 'REDACTED'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'fd178f81-f37b-11ef-b69b-8cc681cfef94'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:32,996 - INFO - Response status: 409
# Response headers:
#     'Content-Length': '230'
#     'Content-Type': 'application/xml'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '883b96f9-d01e-0064-3388-87fdf9000000'
#     'x-ms-client-request-id': 'fd178f81-f37b-11ef-b69b-8cc681cfef94'
#     'x-ms-version': 'REDACTED'
#     'x-ms-error-code': 'ContainerAlreadyExists'
#     'Date': 'Tue, 25 Feb 2025 13:25:33 GMT'
# 2025-02-25 14:25:32,996 - INFO - Container 'ai-news' may already exist: The specified container already exists.
# RequestId:883b96f9-d01e-0064-3388-87fdf9000000
# Time:2025-02-25T13:25:33.4350296Z
# ErrorCode:ContainerAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>ContainerAlreadyExists</Code><Message>The specified container already exists.
# RequestId:883b96f9-d01e-0064-3388-87fdf9000000
# Time:2025-02-25T13:25:33.4350296Z</Message></Error>
# 2025-02-25 14:25:33,003 - INFO - Request URL: 'https://newaifoundry711371036146.blob.core.windows.net/ai-news/news_20250225_132532.json'
# Request method: 'PUT'
# Request headers:
#     'Content-Length': '1080'
#     'x-ms-blob-type': 'REDACTED'
#     'x-ms-version': 'REDACTED'
#     'Content-Type': 'application/octet-stream'
#     'Accept': 'application/xml'
#     'User-Agent': 'azsdk-python-storage-blob/12.19.0 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'x-ms-date': 'REDACTED'
#     'x-ms-client-request-id': 'fd6c447b-f37b-11ef-bfaf-8cc681cfef94'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-02-25 14:25:33,046 - INFO - Response status: 201
# Response headers:
#     'Content-Length': '0'
#     'Content-MD5': 'REDACTED'
#     'Last-Modified': 'Tue, 25 Feb 2025 13:25:33 GMT'
#     'ETag': '"0x8DD559FE1E89CB0"'
#     'Server': 'Windows-Azure-Blob/1.0 Microsoft-HTTPAPI/2.0'
#     'x-ms-request-id': '883b9712-d01e-0064-4988-87fdf9000000'
#     'x-ms-client-request-id': 'fd6c447b-f37b-11ef-bfaf-8cc681cfef94'
#     'x-ms-version': 'REDACTED'
#     'x-ms-content-crc64': 'REDACTED'
#     'x-ms-request-server-encrypted': 'REDACTED'
#     'Date': 'Tue, 25 Feb 2025 13:25:33 GMT'
# 2025-02-25 14:25:33,046 - INFO - News data successfully stored in blob storage: ai-news/news_20250225_132532.json
# 2025-02-25 14:25:33,047 - INFO - Tool outputs: [{'tool_call_id': 'call_XWhE1NoauulVcXkqrqM7gOIU', 'output': 'News data successfully stored in blob storage: ai-news/news_20250225_132532.json'}]
# 2025-02-25 14:25:33,048 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4/submit_tool_outputs?api-version=REDACTED'
# Request method: 'POST'
# Request headers:
#     'Content-Type': 'application/json'
#     'Content-Length': '180'
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'fd731993-f37b-11ef-aaec-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# A body is sent with the request
# 2025-02-25 14:25:33,530 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:33 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:33,532 - INFO - Current run status: RunStatus.REQUIRES_ACTION
# 2025-02-25 14:25:34,534 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'fe55d5ec-f37b-11ef-88bf-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:34,755 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:35 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:34,758 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-02-25 14:25:35,760 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'ff110ba8-f37b-11ef-bfab-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:36,129 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:36 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:36,129 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-02-25 14:25:37,131 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': 'ffe2401d-f37b-11ef-a72e-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:37,370 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:37 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:37,371 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-02-25 14:25:38,373 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '009f93cd-f37c-11ef-8165-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:38,725 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:39 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:38,725 - INFO - Current run status: RunStatus.IN_PROGRESS
# 2025-02-25 14:25:39,728 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/threads/thread_nVDfXSSu3gI9VipDlqITA4K6/runs/run_klkyC0vFnpVAOhasQj2bxep4?api-version=REDACTED'
# Request method: 'GET'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '016e7b02-f37c-11ef-92ca-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:39,952 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:40 GMT'
#     'Content-Type': 'application/json'
#     'Transfer-Encoding': 'chunked'
#     'Connection': 'keep-alive'
#     'Vary': 'REDACTED'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
#     'Content-Encoding': 'REDACTED'
# 2025-02-25 14:25:39,955 - INFO - Current run status: RunStatus.FAILED
# 2025-02-25 14:25:39,955 - INFO - Run finished with status: RunStatus.FAILED
# 2025-02-25 14:25:39,956 - ERROR - Run failed: {'code': 'rate_limit_exceeded', 'message': 'Rate limit is exceeded. Try again in 47 seconds.'}
# 2025-02-25 14:25:39,957 - INFO - Request URL: 'https://swedencentral.api.azureml.ms/agents/v1.0/subscriptions/4c9216b8-3c30-4c2f-8ced-0837fea45954/resourceGroups/basic-agent-setup-713/providers/Microsoft.MachineLearningServices/workspaces/ffollonier-rag-project-713/assistants/asst_OvZdVzilOpUumk54d2YVzX91?api-version=REDACTED'
# Request method: 'DELETE'
# Request headers:
#     'Accept': 'application/json'
#     'x-ms-client-request-id': '0191568f-f37c-11ef-8203-8cc681cfef94'
#     'User-Agent': 'azsdk-python-ai-projects/1.0.0b5 Python/3.11.5 (Windows-10-10.0.26100-SP0)'
#     'Authorization': 'REDACTED'
# No body was attached to the request
# 2025-02-25 14:25:40,244 - INFO - Response status: 200
# Response headers:
#     'Date': 'Tue, 25 Feb 2025 13:25:40 GMT'
#     'Content-Type': 'application/json'
#     'Content-Length': '95'
#     'Connection': 'keep-alive'
#     'Request-Context': 'REDACTED'
#     'x-ms-response-type': 'REDACTED'
#     'x-ms-middleware-request-id': 'REDACTED'
#     'openai-version': 'REDACTED'
#     'openai-organization': 'REDACTED'
#     'X-Request-ID': 'REDACTED'
#     'openai-processing-ms': 'REDACTED'
#     'Strict-Transport-Security': 'REDACTED'
#     'apim-request-id': 'REDACTED'
#     'X-Content-Type-Options': 'REDACTED'
#     'x-ms-region': 'REDACTED'
#     'x-aml-cluster': 'REDACTED'
#     'x-request-time': 'REDACTED'
# 2025-02-25 14:25:40,244 - INFO - Agent deleted successfully.
